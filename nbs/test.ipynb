# %%
from sherloque import LIEnggBlogCrawler, QueryEngine

# %%
c = await LIEnggBlogCrawler.create()
c
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/suchitg/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/suchitg/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# LinkedIn Engineering Blog crawler.

# %%
pages = [
    "https://www.linkedin.com/blog/engineering/ai/how-we-leveraged-vllm-to-power-our-genai-applications",
    "https://www.linkedin.com/blog/engineering/machine-learning/matching-linkedin-members-with-the-right-premium-products",
    "https://www.linkedin.com/blog/engineering/infrastructure/optimizing-linkedin-sales-navigators-search-pipeline-with-spark",
    "https://www.linkedin.com/blog/engineering/scalability/improving-resiliency-and-stability-of-a-large-scale-api",
]

await c.crawl(pages, 2)
# Out:
# 2025-09-21 23:20:03,936 - [INFO] - sherloque.crawler: Starting 0 level of crawling with 4 new pages
# 2025-09-21 23:20:03,936 - [INFO] - sherloque.crawler: Starting crawling for page: https://www.linkedin.com/blog/engineering/ai/how-we-leveraged-vllm-to-power-our-genai-applications
# 2025-09-21 23:20:03,942 - [INFO] - sherloque.crawler: URL https://www.linkedin.com/blog/engineering/ai/how-we-leveraged-vllm-to-power-our-genai-applications already indexed. Skipping ...
# 2025-09-21 23:20:03,942 - [INFO] - sherloque.crawler: Starting crawling for page: https://www.linkedin.com/blog/engineering/machine-learning/matching-linkedin-members-with-the-right-premium-products
# 2025-09-21 23:20:03,950 - [INFO] - sherloque.crawler: URL https://www.linkedin.com/blog/engineering/machine-learning/matching-linkedin-members-with-the-right-premium-products already indexed. Skipping ...
# 2025-09-21 23:20:03,950 - [INFO] - sherloque.crawler: Starting crawling for page: https://www.linkedin.com/blog/engineering/infrastructure/optimizing-linkedin-sales-navigators-search-pipeline-with-spark
# 2025-09-21 23:20:03,957 - [INFO] - sherloque.crawler: URL https://www.linkedin.com/blog/engineering/infrastructure/optimizing-linkedin-sales-navigators-search-pipeline-with-spark already indexed. Skipping ...
# 2025-09-21 23:20:03,957 - [INFO] - sherloque.crawler: Starting crawling for page: https://www.linkedin.com/blog/engineering/scalability/improving-resiliency-and-stability-of-a-large-scale-api
# 2025-09-21 23:20:03,964 - [INFO] - sherloque.crawler: URL https://www.linkedin.com/blog/engineering/scalability/improving-resiliency-and-stability-of-a-large-scale-api already indexed. Skipping ...
# 2025-09-21 23:20:03,964 - [INFO] - sherloque.crawler: Starting 1 level of crawling with 0 new pages

# %%
q = QueryEngine()
q

# %%
await q._get_match_rows("services and monolithic system design")
# Out:
# [(4,), (7,)]
