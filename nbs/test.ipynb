# %%
from src.sherloque import LIEnggBlogCrawler

# %%
c = await LIEnggBlogCrawler.create()
c
# Out:
# name:  create_index_tables
# self:  create_index_tables
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/suchitg/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# LinkedIn Engineering Blog crawler.

# %%
c.__repr__()
# Out:
# 'LinkedIn Engineering Blog crawler.'

# %%
pages = [
    "https://www.linkedin.com/blog/engineering/ai/how-we-leveraged-vllm-to-power-our-genai-applications",
    "https://www.linkedin.com/blog/engineering/machine-learning/matching-linkedin-members-with-the-right-premium-products",
    "https://www.linkedin.com/blog/engineering/infrastructure/optimizing-linkedin-sales-navigators-search-pipeline-with-spark",
    "https://www.linkedin.com/blog/engineering/scalability/improving-resiliency-and-stability-of-a-large-scale-api",
]

await c.crawl(pages, 2)
# Out:
# name:  crawl
# self:  LIEnggBlogCrawler.crawl
# name:  add_to_index
# self:  LIEnggBlogCrawler.add_to_index
# name:  is_indexed
# self:  LIEnggBlogCrawler.is_indexed
# Indexing  https://www.linkedin.com/blog/engineering/ai/how-we-leveraged-vllm-to-power-our-genai-applications
# name:  _get_entry_id
# self:  LIEnggBlogCrawler._get_entry_id
# name:  _get_entry_id
# self:  LIEnggBlogCrawler._get_entry_id
# name:  _get_entry_id
# self:  LIEnggBlogCrawler._get_entry_id
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 8
#       1 pages = [
#       2     "https://www.linkedin.com/blog/engineering/ai/how-we-leveraged-vllm-to-power-our-genai-applications",
#       3     "https://www.linkedin.com/blog/engineering/machine-learning/matching-linkedin-members-with-the-right-premium-products",
#       4     "https://www.linkedin.com/blog/engineering/infrastructure/optimizing-linkedin-sales-navigators-search-pipeline-with-spark",
#       5     "https://www.linkedin.com/blog/engineering/scalability/improving-resiliency-and-stability-of-a-large-scale-api",
#       6 ]
# ----> 8 await c.crawl(pages, 2)
#
# File ~/sherloque/src/config.py:41, in manage_db_cursor.<locals>.decorator.<locals>.create_cursor(*args, **kwargs)
#      38 if is_class_func:
#      39     # inject cursor after `self`
#      40     self_instance, other_args = args[0], args[1:]
# ---> 41     result = await func(self_instance, cursor, *other_args, **kwargs)
#      42 else:
#      43     result = await func(cursor, *args, **kwargs)
#
# File ~/sherloque/src/sherloque/crawler.py:135, in LIEnggBlogCrawler.crawl(self, cursor, pages, depth)
#     132     continue
#     134 soup = BeautifulSoup(c.read(), "html.parser")
# --> 135 await self.add_to_index(page, soup)
#     136 links = await self._get_related_articles_soups(soup)
#     137 for link in links:
#
# File ~/sherloque/src/config.py:41, in manage_db_cursor.<locals>.decorator.<locals>.create_cursor(*args, **kwargs)
#      38 if is_class_func:
#      39     # inject cursor after `self`
#      40     self_instance, other_args = args[0], args[1:]
# ---> 41     result = await func(self_instance, cursor, *other_args, **kwargs)
#      42 else:
#      43     result = await func(cursor, *args, **kwargs)
#
# File ~/sherloque/src/sherloque/crawler.py:63, in LIEnggBlogCrawler.add_to_index(self, cursor, url, soup)
#      60 token = processed_toks[i]
#      61 # handle this better using nltk
#      62 # if tok in ignore_words: continue
# ---> 63 token_id = await self._get_entry_id("token_list", "token", token)
#      64 await cursor.execute(
#      65     "INSERT INTO token_location(url_id, token_id, location) VALUES (?, ?, ?)",
#      66     (url_id, token_id, i)
#      67 )
#
# File ~/sherloque/src/config.py:41, in manage_db_cursor.<locals>.decorator.<locals>.create_cursor(*args, **kwargs)
#      38 if is_class_func:
#      39     # inject cursor after `self`
#      40     self_instance, other_args = args[0], args[1:]
# ---> 41     result = await func(self_instance, cursor, *other_args, **kwargs)
#      42 else:
#      43     result = await func(cursor, *args, **kwargs)
#
# File ~/sherloque/src/sherloque/crawler.py:43, in LIEnggBlogCrawler._get_entry_id(self, cursor, table, field, value)
#      40 if row_id is not None:
#      41     return row_id[0]
# ---> 43 cur = await cursor.execute(
#      44     f"INSERT INTO {table} ({field}) VALUES (?)",
#      45     (value,),
#      46 )
#      48 return cur.lastrowid
#
# File ~/sherloque/.venv/lib/python3.12/site-packages/aiosqlite/cursor.py:40, in Cursor.execute(self, sql, parameters)
#      38 if parameters is None:
#      39     parameters = []
# ---> 40 await self._execute(self._cursor.execute, sql, parameters)
#      41 return self
#
# File ~/sherloque/.venv/lib/python3.12/site-packages/aiosqlite/cursor.py:32, in Cursor._execute(self, fn, *args, **kwargs)
#      30 async def _execute(self, fn, *args, **kwargs):
#      31     """Execute the given function on the shared connection's thread."""
# ---> 32     return await self._conn._execute(fn, *args, **kwargs)
#
# File ~/sherloque/.venv/lib/python3.12/site-packages/aiosqlite/core.py:122, in Connection._execute(self, fn, *args, **kwargs)
#     118 future = asyncio.get_event_loop().create_future()
#     120 self._tx.put_nowait((future, function))
# --> 122 return await future
#
# File ~/sherloque/.venv/lib/python3.12/site-packages/aiosqlite/core.py:105, in Connection.run(self)
#     103 try:
#     104     LOG.debug("executing %s", function)
# --> 105     result = function()
#     106     LOG.debug("operation %s completed", function)
#     107     future.get_loop().call_soon_threadsafe(set_result, future, result)
#
# OperationalError: database is locked
